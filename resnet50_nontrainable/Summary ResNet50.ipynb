# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
lst_dic = {}
for file in [x for x in os.listdir() if x[-3:] == 'csv']:
    name_file = file[:-4]
    read_file = pd.read_csv(file)['val_acc']
    lst_dic[name_file] = read_file

# %%
pd.DataFrame(lst_dic).max()
# Out:
# res_hls_nonpre      0.813651
# res_hls_pre         0.827718
# res_hsv_nonpre      0.575894
# res_hsv_pre         0.591351
# res_lab_nonpre      0.840396
# res_lab_pre         0.863668
# res_luv_nonpre      0.901528
# res_luv_pre         0.893192
# res_rgb             0.893713
# res_xyz_nonpre      0.480201
# res_xyz_pre         0.457451
# res_ycrcb_nonpre    0.883987
# res_ycrcb_pre       0.861410
# res_ydbdr_nonpre    0.484196
# res_ydbdr_pre       0.484891
# res_yuv_nonpre      0.448593
# res_yuv_pre         0.516672
# dtype: float64

# %%
plt.figure(figsize=(15,6))
plt.plot(pd.DataFrame(lst_dic));
