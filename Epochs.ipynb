# %% [markdown]
# <a href="https://colab.research.google.com/github/yevonnaelandrew/galaxy-classification-ensemble/blob/main/All_Color_Space_ResNet50_Non_trainable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Fri Jun  3 17:33:27 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.106.00   Driver Version: 460.106.00   CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A30                 On   | 00000000:03:00.0 Off |                    0 |
# | N/A   34C    P0    28W / 165W |      0MiB / 24258MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
import glob
import pandas as pd
import tensorflow_io as tfio
import matplotlib.pyplot as plt
import numpy as np
import PIL
import pathlib
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
def train_model():
  data_dir = pathlib.Path('content/img_RGB')

  batch_size = 32
  img_height = 128
  img_width = 128

  IMG_SHAPE = (img_height, img_width) + (3,)

  train_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size)

  val_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size)

  class_names = train_ds.class_names

  AUTOTUNE = tf.data.AUTOTUNE
  num_classes = len(class_names)

  train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
  val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

  data_augmentation = Sequential([
    tf.keras.layers.RandomFlip('horizontal'),
    tf.keras.layers.RandomRotation(0.2),
  ])

  # Create the base model from the pre-trained model
  base_model = tf.keras.applications.ResNet50(input_shape=IMG_SHAPE,
                                              include_top=False,
                                              weights='imagenet')
  
  base_model.trainable = False

  inputs = tf.keras.Input(shape=(128, 128, 3))
  x = data_augmentation(inputs)
  x = tf.keras.applications.resnet50.preprocess_input(x)
  x = base_model(x)
  x = tf.keras.layers.MaxPooling2D()(x)
  x = tf.keras.layers.Dropout(0.2)(x)
  x = tf.keras.layers.Flatten()(x)
  x = tf.keras.layers.Dense(512, activation='relu')(x)
  x = tf.keras.layers.Dropout(0.2)(x)
  x = tf.keras.layers.Dense(128, activation='relu')(x)
  outputs = tf.keras.layers.Dense(5)(x)
  model = tf.keras.Model(inputs, outputs)

  base_learning_rate = 0.001

  model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

  epochs=100
  history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs
  )

  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']

  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs_range = range(epochs)

  plt.figure(figsize=(16, 6))
  plt.subplot(1, 2, 1)
  plt.plot(epochs_range, acc, label='Training Accuracy')
  plt.plot(epochs_range, val_acc, label='Validation Accuracy')
  plt.legend(loc='lower right')
  plt.title('Training and Validation Accuracy')

  plt.subplot(1, 2, 2)
  plt.plot(epochs_range, loss, label='Training Loss')
  plt.plot(epochs_range, val_loss, label='Validation Loss')
  plt.legend(loc='upper right')
  plt.title('Training and Validation Loss')
  plt.show()
    
  return {'acc': acc, 'val_acc': val_acc, 'loss': loss, 'val_loss': val_loss}

# %%
ep_100 = train_model()
# Out:
# Found 28793 files belonging to 5 classes.
# Using 23035 files for training.
# Found 28793 files belonging to 5 classes.
# Using 5758 files for validation.
# Epoch 1/100
# 720/720 [==============================] - 21s 24ms/step - loss: 0.6616 - accuracy: 0.7400 - val_loss: 0.5346 - val_accuracy: 0.7746
# Epoch 2/100
# 720/720 [==============================] - 19s 26ms/step - loss: 0.5056 - accuracy: 0.7863 - val_loss: 0.4446 - val_accuracy: 0.8098
# Epoch 3/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.4665 - accuracy: 0.8054 - val_loss: 0.4147 - val_accuracy: 0.8223
# Epoch 4/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.4471 - accuracy: 0.8137 - val_loss: 0.4049 - val_accuracy: 0.8343
# Epoch 5/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.4252 - accuracy: 0.8237 - val_loss: 0.3920 - val_accuracy: 0.8404
# Epoch 6/100
# 720/720 [==============================] - 17s 24ms/step - loss: 0.4186 - accuracy: 0.8289 - val_loss: 0.3827 - val_accuracy: 0.8361
# Epoch 7/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.4063 - accuracy: 0.8319 - val_loss: 0.3798 - val_accuracy: 0.8435
# Epoch 8/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3982 - accuracy: 0.8373 - val_loss: 0.3460 - val_accuracy: 0.8619
# Epoch 9/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3958 - accuracy: 0.8388 - val_loss: 0.3632 - val_accuracy: 0.8559
# Epoch 10/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3905 - accuracy: 0.8412 - val_loss: 0.3505 - val_accuracy: 0.8593
# Epoch 11/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3866 - accuracy: 0.8413 - val_loss: 0.3446 - val_accuracy: 0.8652
# Epoch 12/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3761 - accuracy: 0.8473 - val_loss: 0.3413 - val_accuracy: 0.8654
# Epoch 13/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3739 - accuracy: 0.8500 - val_loss: 0.4153 - val_accuracy: 0.8326
# Epoch 14/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3645 - accuracy: 0.8520 - val_loss: 0.3366 - val_accuracy: 0.8699
# Epoch 15/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3674 - accuracy: 0.8503 - val_loss: 0.3382 - val_accuracy: 0.8696
# Epoch 16/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3564 - accuracy: 0.8573 - val_loss: 0.3349 - val_accuracy: 0.8673
# Epoch 17/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3516 - accuracy: 0.8593 - val_loss: 0.3447 - val_accuracy: 0.8638
# Epoch 18/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3516 - accuracy: 0.8576 - val_loss: 0.3325 - val_accuracy: 0.8715
# Epoch 19/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3504 - accuracy: 0.8582 - val_loss: 0.3213 - val_accuracy: 0.8706
# Epoch 20/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3478 - accuracy: 0.8587 - val_loss: 0.3400 - val_accuracy: 0.8607
# Epoch 21/100
# 720/720 [==============================] - 17s 24ms/step - loss: 0.3405 - accuracy: 0.8614 - val_loss: 0.3211 - val_accuracy: 0.8758
# Epoch 22/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3411 - accuracy: 0.8637 - val_loss: 0.3171 - val_accuracy: 0.8751
# Epoch 23/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3432 - accuracy: 0.8625 - val_loss: 0.3166 - val_accuracy: 0.8776
# Epoch 24/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3355 - accuracy: 0.8633 - val_loss: 0.3240 - val_accuracy: 0.8739
# Epoch 25/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3382 - accuracy: 0.8667 - val_loss: 0.3124 - val_accuracy: 0.8758
# Epoch 26/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3317 - accuracy: 0.8674 - val_loss: 0.3112 - val_accuracy: 0.8790
# Epoch 27/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3370 - accuracy: 0.8644 - val_loss: 0.3219 - val_accuracy: 0.8755
# Epoch 28/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3315 - accuracy: 0.8672 - val_loss: 0.3222 - val_accuracy: 0.8704
# Epoch 29/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3299 - accuracy: 0.8688 - val_loss: 0.3531 - val_accuracy: 0.8588
# Epoch 30/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3245 - accuracy: 0.8722 - val_loss: 0.3125 - val_accuracy: 0.8784
# Epoch 31/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3204 - accuracy: 0.8715 - val_loss: 0.3351 - val_accuracy: 0.8664
# Epoch 32/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3233 - accuracy: 0.8707 - val_loss: 0.3173 - val_accuracy: 0.8755
# Epoch 33/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3242 - accuracy: 0.8705 - val_loss: 0.3095 - val_accuracy: 0.8817
# Epoch 34/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3158 - accuracy: 0.8726 - val_loss: 0.3265 - val_accuracy: 0.8730
# Epoch 35/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3224 - accuracy: 0.8703 - val_loss: 0.3273 - val_accuracy: 0.8724
# Epoch 36/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3166 - accuracy: 0.8722 - val_loss: 0.3027 - val_accuracy: 0.8840
# Epoch 37/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3184 - accuracy: 0.8725 - val_loss: 0.3206 - val_accuracy: 0.8750
# Epoch 38/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3112 - accuracy: 0.8760 - val_loss: 0.3149 - val_accuracy: 0.8793
# Epoch 39/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3110 - accuracy: 0.8755 - val_loss: 0.3096 - val_accuracy: 0.8840
# Epoch 40/100
# 720/720 [==============================] - 19s 26ms/step - loss: 0.3121 - accuracy: 0.8766 - val_loss: 0.3165 - val_accuracy: 0.8748
# Epoch 41/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3139 - accuracy: 0.8734 - val_loss: 0.3194 - val_accuracy: 0.8777
# Epoch 42/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3132 - accuracy: 0.8735 - val_loss: 0.3082 - val_accuracy: 0.8770
# Epoch 43/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3090 - accuracy: 0.8782 - val_loss: 0.2996 - val_accuracy: 0.8826
# Epoch 44/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3100 - accuracy: 0.8763 - val_loss: 0.3135 - val_accuracy: 0.8760
# Epoch 45/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3092 - accuracy: 0.8771 - val_loss: 0.2967 - val_accuracy: 0.8824
# Epoch 46/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3057 - accuracy: 0.8811 - val_loss: 0.3201 - val_accuracy: 0.8786
# Epoch 47/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3060 - accuracy: 0.8781 - val_loss: 0.3124 - val_accuracy: 0.8798
# Epoch 48/100
# 720/720 [==============================] - 19s 26ms/step - loss: 0.3085 - accuracy: 0.8767 - val_loss: 0.3087 - val_accuracy: 0.8805
# Epoch 49/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3065 - accuracy: 0.8789 - val_loss: 0.3082 - val_accuracy: 0.8807
# Epoch 50/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3006 - accuracy: 0.8787 - val_loss: 0.3087 - val_accuracy: 0.8819
# Epoch 51/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.2979 - accuracy: 0.8814 - val_loss: 0.3313 - val_accuracy: 0.8748
# Epoch 52/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.2966 - accuracy: 0.8812 - val_loss: 0.3073 - val_accuracy: 0.8843
# Epoch 53/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.2992 - accuracy: 0.8810 - val_loss: 0.3142 - val_accuracy: 0.8769
# Epoch 54/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3013 - accuracy: 0.8819 - val_loss: 0.3097 - val_accuracy: 0.8835
# Epoch 55/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.2982 - accuracy: 0.8834 - val_loss: 0.3242 - val_accuracy: 0.8739
# Epoch 56/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3000 - accuracy: 0.8804 - val_loss: 0.3061 - val_accuracy: 0.8790
# Epoch 57/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.2997 - accuracy: 0.8791 - val_loss: 0.2998 - val_accuracy: 0.8829
# Epoch 58/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.2938 - accuracy: 0.8829 - val_loss: 0.2953 - val_accuracy: 0.8847
# Epoch 59/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.2973 - accuracy: 0.8828 - val_loss: 0.3151 - val_accuracy: 0.8779
# Epoch 60/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.2914 - accuracy: 0.8841 - val_loss: 0.2996 - val_accuracy: 0.8842
# Epoch 61/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.2922 - accuracy: 0.8850 - val_loss: 0.2981 - val_accuracy: 0.8871
# Epoch 62/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.2961 - accuracy: 0.8830 - val_loss: 0.3047 - val_accuracy: 0.8767
# Epoch 63/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.2882 - accuracy: 0.8839 - val_loss: 0.3105 - val_accuracy: 0.8807
# Epoch 64/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.2927 - accuracy: 0.8843 - val_loss: 0.3110 - val_accuracy: 0.8777
# Epoch 65/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.2882 - accuracy: 0.8847 - val_loss: 0.2994 - val_accuracy: 0.8854
# Epoch 66/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.2880 - accuracy: 0.8858 - val_loss: 0.2921 - val_accuracy: 0.8859
# Epoch 67/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.2973 - accuracy: 0.8823 - val_loss: 0.3040 - val_accuracy: 0.8842
# Epoch 68/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.2882 - accuracy: 0.8869 - val_loss: 0.2988 - val_accuracy: 0.8850
# Epoch 69/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.2897 - accuracy: 0.8840 - val_loss: 0.2978 - val_accuracy: 0.8810
# Epoch 70/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.2916 - accuracy: 0.8834 - val_loss: 0.3086 - val_accuracy: 0.8739
# Epoch 71/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.2826 - accuracy: 0.8892 - val_loss: 0.3034 - val_accuracy: 0.8854
# Epoch 72/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.2887 - accuracy: 0.8877 - val_loss: 0.3046 - val_accuracy: 0.8817
# Epoch 73/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.2845 - accuracy: 0.8870 - val_loss: 0.2925 - val_accuracy: 0.8904
# Epoch 74/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.2844 - accuracy: 0.8857 - val_loss: 0.2892 - val_accuracy: 0.8890
# Epoch 75/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.2824 - accuracy: 0.8866 - val_loss: 0.3014 - val_accuracy: 0.8819
# Epoch 76/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.2825 - accuracy: 0.8910 - val_loss: 0.3021 - val_accuracy: 0.8849
# Epoch 77/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.2873 - accuracy: 0.8859 - val_loss: 0.2944 - val_accuracy: 0.8889
# Epoch 78/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.2849 - accuracy: 0.8869 - val_loss: 0.2927 - val_accuracy: 0.8862
# Epoch 79/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.2825 - accuracy: 0.8904 - val_loss: 0.2898 - val_accuracy: 0.8887
# Epoch 80/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.2785 - accuracy: 0.8900 - val_loss: 0.3036 - val_accuracy: 0.8849
# Epoch 81/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.2796 - accuracy: 0.8901 - val_loss: 0.2974 - val_accuracy: 0.8828
# Epoch 82/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.2758 - accuracy: 0.8906 - val_loss: 0.3005 - val_accuracy: 0.8864
# Epoch 83/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.2801 - accuracy: 0.8883 - val_loss: 0.2850 - val_accuracy: 0.8909
# Epoch 84/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.2813 - accuracy: 0.8868 - val_loss: 0.3121 - val_accuracy: 0.8746
# Epoch 85/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.2817 - accuracy: 0.8884 - val_loss: 0.2906 - val_accuracy: 0.8856
# Epoch 86/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.2761 - accuracy: 0.8884 - val_loss: 0.3042 - val_accuracy: 0.8821
# Epoch 87/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.2819 - accuracy: 0.8895 - val_loss: 0.3231 - val_accuracy: 0.8750
# Epoch 88/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.2803 - accuracy: 0.8912 - val_loss: 0.3043 - val_accuracy: 0.8784
# Epoch 89/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.2760 - accuracy: 0.8896 - val_loss: 0.2902 - val_accuracy: 0.8913
# Epoch 90/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.2762 - accuracy: 0.8904 - val_loss: 0.2947 - val_accuracy: 0.8864
# Epoch 91/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.2760 - accuracy: 0.8897 - val_loss: 0.2965 - val_accuracy: 0.8889
# Epoch 92/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.2750 - accuracy: 0.8923 - val_loss: 0.2884 - val_accuracy: 0.8878
# Epoch 93/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.2768 - accuracy: 0.8876 - val_loss: 0.2920 - val_accuracy: 0.8875
# Epoch 94/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.2803 - accuracy: 0.8883 - val_loss: 0.3012 - val_accuracy: 0.8856
# Epoch 95/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.2741 - accuracy: 0.8891 - val_loss: 0.2951 - val_accuracy: 0.8876
# Epoch 96/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.2809 - accuracy: 0.8901 - val_loss: 0.2923 - val_accuracy: 0.8876
# Epoch 97/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.2720 - accuracy: 0.8917 - val_loss: 0.2939 - val_accuracy: 0.8901
# Epoch 98/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.2715 - accuracy: 0.8913 - val_loss: 0.2887 - val_accuracy: 0.8890
# Epoch 99/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.2774 - accuracy: 0.8900 - val_loss: 0.3037 - val_accuracy: 0.8829
# Epoch 100/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.2807 - accuracy: 0.8889 - val_loss: 0.2931 - val_accuracy: 0.8826

# %%
ep_100_def = train_model()
# Out:
# Found 28793 files belonging to 5 classes.
# Using 23035 files for training.
# Found 28793 files belonging to 5 classes.
# Using 5758 files for validation.
# Epoch 1/100
# 720/720 [==============================] - 26s 27ms/step - loss: 0.7260 - accuracy: 0.7367 - val_loss: 0.4728 - val_accuracy: 0.7886
# Epoch 2/100
# 720/720 [==============================] - 18s 25ms/step - loss: 0.5130 - accuracy: 0.7848 - val_loss: 0.4439 - val_accuracy: 0.8126
# Epoch 3/100
# 720/720 [==============================] - 17s 24ms/step - loss: 0.4815 - accuracy: 0.7974 - val_loss: 0.4040 - val_accuracy: 0.8296
# Epoch 4/100
# 720/720 [==============================] - 17s 24ms/step - loss: 0.4546 - accuracy: 0.8092 - val_loss: 0.4246 - val_accuracy: 0.8255
# Epoch 5/100
# 720/720 [==============================] - 19s 27ms/step - loss: 0.4431 - accuracy: 0.8179 - val_loss: 0.3862 - val_accuracy: 0.8437
# Epoch 6/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.4235 - accuracy: 0.8257 - val_loss: 0.4147 - val_accuracy: 0.8328
# Epoch 7/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.4129 - accuracy: 0.8343 - val_loss: 0.3527 - val_accuracy: 0.8578
# Epoch 8/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.4040 - accuracy: 0.8364 - val_loss: 0.3836 - val_accuracy: 0.8421
# Epoch 9/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.4041 - accuracy: 0.8350 - val_loss: 0.3844 - val_accuracy: 0.8468
# Epoch 10/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3982 - accuracy: 0.8399 - val_loss: 0.3551 - val_accuracy: 0.8595
# Epoch 11/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3915 - accuracy: 0.8417 - val_loss: 0.3795 - val_accuracy: 0.8477
# Epoch 12/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3860 - accuracy: 0.8456 - val_loss: 0.3512 - val_accuracy: 0.8581
# Epoch 13/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3846 - accuracy: 0.8433 - val_loss: 0.3500 - val_accuracy: 0.8625
# Epoch 14/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3815 - accuracy: 0.8470 - val_loss: 0.3438 - val_accuracy: 0.8680
# Epoch 15/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3750 - accuracy: 0.8490 - val_loss: 0.3497 - val_accuracy: 0.8663
# Epoch 16/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3808 - accuracy: 0.8481 - val_loss: 0.3465 - val_accuracy: 0.8614
# Epoch 17/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3676 - accuracy: 0.8530 - val_loss: 0.3414 - val_accuracy: 0.8678
# Epoch 18/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3689 - accuracy: 0.8495 - val_loss: 0.3405 - val_accuracy: 0.8673
# Epoch 19/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3656 - accuracy: 0.8549 - val_loss: 0.3549 - val_accuracy: 0.8593
# Epoch 20/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3652 - accuracy: 0.8547 - val_loss: 0.3561 - val_accuracy: 0.8592
# Epoch 21/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3597 - accuracy: 0.8572 - val_loss: 0.3386 - val_accuracy: 0.8682
# Epoch 22/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3561 - accuracy: 0.8565 - val_loss: 0.3379 - val_accuracy: 0.8715
# Epoch 23/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3612 - accuracy: 0.8548 - val_loss: 0.3280 - val_accuracy: 0.8724
# Epoch 24/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3527 - accuracy: 0.8559 - val_loss: 0.3509 - val_accuracy: 0.8673
# Epoch 25/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3497 - accuracy: 0.8606 - val_loss: 0.3408 - val_accuracy: 0.8651
# Epoch 26/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3609 - accuracy: 0.8575 - val_loss: 0.3526 - val_accuracy: 0.8623
# Epoch 27/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3471 - accuracy: 0.8595 - val_loss: 0.3282 - val_accuracy: 0.8734
# Epoch 28/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3509 - accuracy: 0.8616 - val_loss: 0.3244 - val_accuracy: 0.8750
# Epoch 29/100
# 720/720 [==============================] - 18s 25ms/step - loss: 0.3526 - accuracy: 0.8611 - val_loss: 0.3312 - val_accuracy: 0.8710
# Epoch 30/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3499 - accuracy: 0.8613 - val_loss: 0.3476 - val_accuracy: 0.8638
# Epoch 31/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3466 - accuracy: 0.8608 - val_loss: 0.3379 - val_accuracy: 0.8656
# Epoch 32/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3471 - accuracy: 0.8601 - val_loss: 0.3318 - val_accuracy: 0.8675
# Epoch 33/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3375 - accuracy: 0.8656 - val_loss: 0.3258 - val_accuracy: 0.8711
# Epoch 34/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3408 - accuracy: 0.8632 - val_loss: 0.3453 - val_accuracy: 0.8626
# Epoch 35/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3425 - accuracy: 0.8618 - val_loss: 0.3322 - val_accuracy: 0.8743
# Epoch 36/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3368 - accuracy: 0.8666 - val_loss: 0.3134 - val_accuracy: 0.8819
# Epoch 37/100
# 720/720 [==============================] - 18s 26ms/step - loss: 0.3348 - accuracy: 0.8656 - val_loss: 0.3445 - val_accuracy: 0.8744
# Epoch 38/100
# 720/720 [==============================] - 19s 26ms/step - loss: 0.3349 - accuracy: 0.8655 - val_loss: 0.3254 - val_accuracy: 0.8739
# Epoch 39/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3346 - accuracy: 0.8662 - val_loss: 0.3195 - val_accuracy: 0.8817
# Epoch 40/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3370 - accuracy: 0.8659 - val_loss: 0.3233 - val_accuracy: 0.8765
# Epoch 41/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3336 - accuracy: 0.8680 - val_loss: 0.3260 - val_accuracy: 0.8819
# Epoch 42/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3372 - accuracy: 0.8662 - val_loss: 0.3190 - val_accuracy: 0.8784
# Epoch 43/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3299 - accuracy: 0.8662 - val_loss: 0.3135 - val_accuracy: 0.8765
# Epoch 44/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3300 - accuracy: 0.8693 - val_loss: 0.3231 - val_accuracy: 0.8744
# Epoch 45/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3317 - accuracy: 0.8698 - val_loss: 0.3263 - val_accuracy: 0.8727
# Epoch 46/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3310 - accuracy: 0.8715 - val_loss: 0.3131 - val_accuracy: 0.8774
# Epoch 47/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3267 - accuracy: 0.8696 - val_loss: 0.3175 - val_accuracy: 0.8701
# Epoch 48/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3302 - accuracy: 0.8700 - val_loss: 0.3124 - val_accuracy: 0.8828
# Epoch 49/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3246 - accuracy: 0.8713 - val_loss: 0.3100 - val_accuracy: 0.8798
# Epoch 50/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3286 - accuracy: 0.8673 - val_loss: 0.3123 - val_accuracy: 0.8765
# Epoch 51/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3350 - accuracy: 0.8671 - val_loss: 0.3104 - val_accuracy: 0.8823
# Epoch 52/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3278 - accuracy: 0.8699 - val_loss: 0.3052 - val_accuracy: 0.8845
# Epoch 53/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3278 - accuracy: 0.8714 - val_loss: 0.3289 - val_accuracy: 0.8680
# Epoch 54/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3222 - accuracy: 0.8735 - val_loss: 0.3223 - val_accuracy: 0.8805
# Epoch 55/100
# 720/720 [==============================] - 19s 27ms/step - loss: 0.3237 - accuracy: 0.8709 - val_loss: 0.3106 - val_accuracy: 0.8788
# Epoch 56/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3204 - accuracy: 0.8758 - val_loss: 0.3026 - val_accuracy: 0.8805
# Epoch 57/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3220 - accuracy: 0.8709 - val_loss: 0.3089 - val_accuracy: 0.8829
# Epoch 58/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3270 - accuracy: 0.8708 - val_loss: 0.3439 - val_accuracy: 0.8678
# Epoch 59/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3216 - accuracy: 0.8725 - val_loss: 0.3120 - val_accuracy: 0.8803
# Epoch 60/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3200 - accuracy: 0.8728 - val_loss: 0.3027 - val_accuracy: 0.8826
# Epoch 61/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3195 - accuracy: 0.8747 - val_loss: 0.3114 - val_accuracy: 0.8836
# Epoch 62/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3222 - accuracy: 0.8709 - val_loss: 0.3208 - val_accuracy: 0.8805
# Epoch 63/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3213 - accuracy: 0.8731 - val_loss: 0.3112 - val_accuracy: 0.8757
# Epoch 64/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3210 - accuracy: 0.8720 - val_loss: 0.3106 - val_accuracy: 0.8784
# Epoch 65/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3233 - accuracy: 0.8718 - val_loss: 0.3112 - val_accuracy: 0.8819
# Epoch 66/100
# 720/720 [==============================] - 19s 26ms/step - loss: 0.3171 - accuracy: 0.8730 - val_loss: 0.2991 - val_accuracy: 0.8814
# Epoch 67/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3193 - accuracy: 0.8745 - val_loss: 0.3062 - val_accuracy: 0.8821
# Epoch 68/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3194 - accuracy: 0.8727 - val_loss: 0.3012 - val_accuracy: 0.8868
# Epoch 69/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3175 - accuracy: 0.8759 - val_loss: 0.2984 - val_accuracy: 0.8880
# Epoch 70/100
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3267 - accuracy: 0.8702 - val_loss: 0.3056 - val_accuracy: 0.8836
# Epoch 71/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3103 - accuracy: 0.8748 - val_loss: 0.3214 - val_accuracy: 0.8824
# Epoch 72/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3198 - accuracy: 0.8738 - val_loss: 0.3205 - val_accuracy: 0.8767
# Epoch 73/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3134 - accuracy: 0.8748 - val_loss: 0.3025 - val_accuracy: 0.8850
# Epoch 74/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3165 - accuracy: 0.8755 - val_loss: 0.3321 - val_accuracy: 0.8748
# Epoch 75/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3068 - accuracy: 0.8813 - val_loss: 0.2988 - val_accuracy: 0.8824
# Epoch 76/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3149 - accuracy: 0.8752 - val_loss: 0.3246 - val_accuracy: 0.8730
# Epoch 77/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3124 - accuracy: 0.8752 - val_loss: 0.3377 - val_accuracy: 0.8644
# Epoch 78/100
# 720/720 [==============================] - 19s 26ms/step - loss: 0.3173 - accuracy: 0.8767 - val_loss: 0.3082 - val_accuracy: 0.8821
# Epoch 79/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3166 - accuracy: 0.8745 - val_loss: 0.2955 - val_accuracy: 0.8826
# Epoch 80/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3044 - accuracy: 0.8785 - val_loss: 0.3043 - val_accuracy: 0.8779
# Epoch 81/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3078 - accuracy: 0.8764 - val_loss: 0.3169 - val_accuracy: 0.8741
# Epoch 82/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3128 - accuracy: 0.8769 - val_loss: 0.3198 - val_accuracy: 0.8803
# Epoch 83/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3108 - accuracy: 0.8784 - val_loss: 0.3079 - val_accuracy: 0.8819
# Epoch 84/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3135 - accuracy: 0.8788 - val_loss: 0.3031 - val_accuracy: 0.8823
# Epoch 85/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3109 - accuracy: 0.8775 - val_loss: 0.3115 - val_accuracy: 0.8763
# Epoch 86/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3132 - accuracy: 0.8768 - val_loss: 0.3170 - val_accuracy: 0.8757
# Epoch 87/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3202 - accuracy: 0.8774 - val_loss: 0.3159 - val_accuracy: 0.8802
# Epoch 88/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3074 - accuracy: 0.8774 - val_loss: 0.3053 - val_accuracy: 0.8873
# Epoch 89/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3195 - accuracy: 0.8762 - val_loss: 0.3214 - val_accuracy: 0.8763
# Epoch 90/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3084 - accuracy: 0.8785 - val_loss: 0.3015 - val_accuracy: 0.8817
# Epoch 91/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3069 - accuracy: 0.8779 - val_loss: 0.3020 - val_accuracy: 0.8859
# Epoch 92/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3080 - accuracy: 0.8785 - val_loss: 0.3188 - val_accuracy: 0.8737
# Epoch 93/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3076 - accuracy: 0.8790 - val_loss: 0.3099 - val_accuracy: 0.8810
# Epoch 94/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3060 - accuracy: 0.8782 - val_loss: 0.3143 - val_accuracy: 0.8849
# Epoch 95/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3097 - accuracy: 0.8810 - val_loss: 0.3074 - val_accuracy: 0.8786
# Epoch 96/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3022 - accuracy: 0.8815 - val_loss: 0.3019 - val_accuracy: 0.8845
# Epoch 97/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3055 - accuracy: 0.8772 - val_loss: 0.3161 - val_accuracy: 0.8770
# Epoch 98/100
# 720/720 [==============================] - 19s 26ms/step - loss: 0.3070 - accuracy: 0.8783 - val_loss: 0.3122 - val_accuracy: 0.8760
# Epoch 99/100
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3058 - accuracy: 0.8803 - val_loss: 0.2998 - val_accuracy: 0.8864
# Epoch 100/100
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3082 - accuracy: 0.8804 - val_loss: 0.3198 - val_accuracy: 0.8770

# %%
# !mkdir epochs
# pd.DataFrame(ep_100).to_csv("epochs/ep_100.csv", index=False)
pd.DataFrame(ep_100_def).to_csv("epochs/ep_100_def.csv", index=False)
