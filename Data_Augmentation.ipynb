# %% [markdown]
# <a href="https://colab.research.google.com/github/yevonnaelandrew/galaxy-classification-ensemble/blob/main/All_Color_Space_ResNet50_Non_trainable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Thu Jun  2 17:44:53 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.106.00   Driver Version: 460.106.00   CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A30                 On   | 00000000:03:00.0 Off |                    0 |
# | N/A   39C    P0    54W / 165W |      0MiB / 24258MiB |    100%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
import glob
import pandas as pd
import tensorflow_io as tfio
import matplotlib.pyplot as plt
import numpy as np
import PIL
import pathlib
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
def train_model():
  data_dir = pathlib.Path('content/img_RGB')

  batch_size = 32
  img_height = 128
  img_width = 128

  IMG_SHAPE = (img_height, img_width) + (3,)

  train_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size)

  val_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size)

  class_names = train_ds.class_names

  AUTOTUNE = tf.data.AUTOTUNE
  num_classes = len(class_names)

  train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
  val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

  data_augmentation = Sequential([
    tf.keras.layers.RandomFlip('horizontal'),
    tf.keras.layers.RandomRotation(0.2),
  ])

  # Create the base model from the pre-trained model
  base_model = tf.keras.applications.ResNet50(input_shape=IMG_SHAPE,
                                              include_top=False,
                                              weights='imagenet')
  
  base_model.trainable = False

  inputs = tf.keras.Input(shape=(128, 128, 3))
  x = data_augmentation(inputs)
  x = tf.keras.applications.resnet50.preprocess_input(x)
  x = base_model(x)
  x = tf.keras.layers.MaxPooling2D()(x)
  x = tf.keras.layers.Dropout(0.2)(x)
  x = tf.keras.layers.Flatten()(x)
  x = tf.keras.layers.Dense(512, activation='relu')(x)
  x = tf.keras.layers.Dropout(0.2)(x)
  x = tf.keras.layers.Dense(128, activation='relu')(x)
  outputs = tf.keras.layers.Dense(5)(x)
  model = tf.keras.Model(inputs, outputs)

  # base_learning_rate = 0.0005

  model.compile(optimizer=tf.keras.optimizers.Adam(),#learning_rate=base_learning_rate),3
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

  epochs=25
  history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs
  )

  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']

  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs_range = range(epochs)

  plt.figure(figsize=(16, 6))
  plt.subplot(1, 2, 1)
  plt.plot(epochs_range, acc, label='Training Accuracy')
  plt.plot(epochs_range, val_acc, label='Validation Accuracy')
  plt.legend(loc='lower right')
  plt.title('Training and Validation Accuracy')

  plt.subplot(1, 2, 2)
  plt.plot(epochs_range, loss, label='Training Loss')
  plt.plot(epochs_range, val_loss, label='Validation Loss')
  plt.legend(loc='upper right')
  plt.title('Training and Validation Loss')
  plt.show()
    
  return {'acc': acc, 'val_acc': val_acc, 'loss': loss, 'val_loss': val_loss}

# %%
with_augmentation = train_model()
# Out:
# Found 28793 files belonging to 5 classes.
# Using 23035 files for training.
# Found 28793 files belonging to 5 classes.
# Using 5758 files for validation.
# Epoch 1/25
# 720/720 [==============================] - 26s 26ms/step - loss: 0.6675 - accuracy: 0.7427 - val_loss: 0.5139 - val_accuracy: 0.7760
# Epoch 2/25
# 720/720 [==============================] - 18s 26ms/step - loss: 0.4904 - accuracy: 0.7945 - val_loss: 0.4404 - val_accuracy: 0.8189
# Epoch 3/25
# 720/720 [==============================] - 18s 24ms/step - loss: 0.4616 - accuracy: 0.8063 - val_loss: 0.4646 - val_accuracy: 0.8020
# Epoch 4/25
# 720/720 [==============================] - 17s 24ms/step - loss: 0.4409 - accuracy: 0.8174 - val_loss: 0.3987 - val_accuracy: 0.8361
# Epoch 5/25
# 720/720 [==============================] - 17s 24ms/step - loss: 0.4207 - accuracy: 0.8274 - val_loss: 0.3773 - val_accuracy: 0.8460
# Epoch 6/25
# 720/720 [==============================] - 17s 24ms/step - loss: 0.4110 - accuracy: 0.8309 - val_loss: 0.3710 - val_accuracy: 0.8512
# Epoch 7/25
# 720/720 [==============================] - 17s 23ms/step - loss: 0.4036 - accuracy: 0.8382 - val_loss: 0.3640 - val_accuracy: 0.8536
# Epoch 8/25
# 720/720 [==============================] - 17s 23ms/step - loss: 0.4028 - accuracy: 0.8365 - val_loss: 0.3828 - val_accuracy: 0.8494
# Epoch 9/25
# 720/720 [==============================] - 17s 24ms/step - loss: 0.3933 - accuracy: 0.8422 - val_loss: 0.3599 - val_accuracy: 0.8579
# Epoch 10/25
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3847 - accuracy: 0.8473 - val_loss: 0.3482 - val_accuracy: 0.8593
# Epoch 11/25
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3830 - accuracy: 0.8451 - val_loss: 0.3423 - val_accuracy: 0.8692
# Epoch 12/25
# 720/720 [==============================] - 17s 24ms/step - loss: 0.3820 - accuracy: 0.8487 - val_loss: 0.3449 - val_accuracy: 0.8626
# Epoch 13/25
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3734 - accuracy: 0.8535 - val_loss: 0.3723 - val_accuracy: 0.8491
# Epoch 14/25
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3739 - accuracy: 0.8520 - val_loss: 0.3936 - val_accuracy: 0.8437
# Epoch 15/25
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3726 - accuracy: 0.8486 - val_loss: 0.3364 - val_accuracy: 0.8645
# Epoch 16/25
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3706 - accuracy: 0.8507 - val_loss: 0.3533 - val_accuracy: 0.8567
# Epoch 17/25
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3628 - accuracy: 0.8534 - val_loss: 0.3657 - val_accuracy: 0.8565
# Epoch 18/25
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3641 - accuracy: 0.8557 - val_loss: 0.3733 - val_accuracy: 0.8512
# Epoch 19/25
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3593 - accuracy: 0.8568 - val_loss: 0.3666 - val_accuracy: 0.8592
# Epoch 20/25
# 720/720 [==============================] - 17s 24ms/step - loss: 0.3613 - accuracy: 0.8564 - val_loss: 0.3279 - val_accuracy: 0.8774
# Epoch 21/25
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3465 - accuracy: 0.8637 - val_loss: 0.3332 - val_accuracy: 0.8692
# Epoch 22/25
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3556 - accuracy: 0.8622 - val_loss: 0.3369 - val_accuracy: 0.8651
# Epoch 23/25
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3526 - accuracy: 0.8607 - val_loss: 0.3353 - val_accuracy: 0.8725
# Epoch 24/25
# 720/720 [==============================] - 17s 24ms/step - loss: 0.3452 - accuracy: 0.8636 - val_loss: 0.3367 - val_accuracy: 0.8715
# Epoch 25/25
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3476 - accuracy: 0.8623 - val_loss: 0.3414 - val_accuracy: 0.8630

# %%
# !mkdir with_augmentation
pd.DataFrame(with_augmentation).to_csv("with_augmentation/with_augmentation.csv", index=False)
