# %% [markdown]
# <a href="https://colab.research.google.com/github/yevonnaelandrew/galaxy-classification-ensemble/blob/main/All_Color_Space_ResNet50_Non_trainable.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
gpu_info = !nvidia-smi
gpu_info = '\n'.join(gpu_info)
if gpu_info.find('failed') >= 0:
  print('Not connected to a GPU')
else:
  print(gpu_info)
# Out:
# Thu Jun  2 17:55:30 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.106.00   Driver Version: 460.106.00   CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  A30                 On   | 00000000:03:00.0 Off |                    0 |
# | N/A   37C    P0    29W / 165W |      0MiB / 24258MiB |      0%      Default |
# |                               |                      |             Disabled |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
import os
import glob
import pandas as pd
import tensorflow_io as tfio
import matplotlib.pyplot as plt
import numpy as np
import PIL
import pathlib
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %%
def train_model():
  data_dir = pathlib.Path('content/img_RGB')

  batch_size = 32
  img_height = 128
  img_width = 128

  IMG_SHAPE = (img_height, img_width) + (3,)

  train_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size)

  val_ds = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=(img_height, img_width),
    batch_size=batch_size)

  class_names = train_ds.class_names

  AUTOTUNE = tf.data.AUTOTUNE
  num_classes = len(class_names)

  train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
  val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

  data_augmentation = Sequential([
    tf.keras.layers.RandomFlip('horizontal'),
    tf.keras.layers.RandomRotation(0.2),
  ])

  # Create the base model from the pre-trained model
  base_model = tf.keras.applications.ResNet50(input_shape=IMG_SHAPE,
                                              include_top=False,
                                              weights='imagenet')
  
  base_model.trainable = False

  inputs = tf.keras.Input(shape=(128, 128, 3))
  x = data_augmentation(inputs)
  x = tf.keras.applications.resnet50.preprocess_input(x)
  x = base_model(x)
  x = tf.keras.layers.MaxPooling2D()(x)
  x = tf.keras.layers.Dropout(0.2)(x)
  x = tf.keras.layers.Flatten()(x)
  x = tf.keras.layers.Dense(512, activation='relu')(x)
  x = tf.keras.layers.Dropout(0.2)(x)
  x = tf.keras.layers.Dense(128, activation='relu')(x)
  outputs = tf.keras.layers.Dense(5)(x)
  model = tf.keras.Model(inputs, outputs)

  base_learning_rate = 0.0005

  model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=base_learning_rate),
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

  epochs=25
  history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=epochs
  )

  acc = history.history['accuracy']
  val_acc = history.history['val_accuracy']

  loss = history.history['loss']
  val_loss = history.history['val_loss']

  epochs_range = range(epochs)

  plt.figure(figsize=(16, 6))
  plt.subplot(1, 2, 1)
  plt.plot(epochs_range, acc, label='Training Accuracy')
  plt.plot(epochs_range, val_acc, label='Validation Accuracy')
  plt.legend(loc='lower right')
  plt.title('Training and Validation Accuracy')

  plt.subplot(1, 2, 2)
  plt.plot(epochs_range, loss, label='Training Loss')
  plt.plot(epochs_range, val_loss, label='Validation Loss')
  plt.legend(loc='upper right')
  plt.title('Training and Validation Loss')
  plt.show()
    
  return {'acc': acc, 'val_acc': val_acc, 'loss': loss, 'val_loss': val_loss}

# %%
rate0_01 = train_model()
# Out:
# Found 28793 files belonging to 5 classes.
# Using 23035 files for training.
# Found 28793 files belonging to 5 classes.
# Using 5758 files for validation.
# Epoch 1/25
# 720/720 [==============================] - 27s 27ms/step - loss: 2.6497 - accuracy: 0.7210 - val_loss: 0.5557 - val_accuracy: 0.7774
# Epoch 2/25
# 720/720 [==============================] - 18s 24ms/step - loss: 0.5748 - accuracy: 0.7632 - val_loss: 0.5468 - val_accuracy: 0.7461
# Epoch 3/25
# 720/720 [==============================] - 17s 24ms/step - loss: 0.5552 - accuracy: 0.7760 - val_loss: 0.4913 - val_accuracy: 0.8025
# Epoch 4/25
# 720/720 [==============================] - 18s 24ms/step - loss: 0.5444 - accuracy: 0.7808 - val_loss: 0.4644 - val_accuracy: 0.8227
# Epoch 5/25
# 720/720 [==============================] - 17s 24ms/step - loss: 0.5542 - accuracy: 0.7835 - val_loss: 0.5548 - val_accuracy: 0.7534
# Epoch 6/25
# 720/720 [==============================] - 18s 25ms/step - loss: 0.5698 - accuracy: 0.7797 - val_loss: 0.5326 - val_accuracy: 0.7965
# Epoch 7/25
# 720/720 [==============================] - 18s 24ms/step - loss: 0.5946 - accuracy: 0.7668 - val_loss: 0.5673 - val_accuracy: 0.8187
# Epoch 8/25
# 720/720 [==============================] - 17s 24ms/step - loss: 0.5872 - accuracy: 0.7741 - val_loss: 0.5294 - val_accuracy: 0.7801
# Epoch 9/25
# 720/720 [==============================] - 17s 24ms/step - loss: 0.5698 - accuracy: 0.7753 - val_loss: 0.5054 - val_accuracy: 0.7949
# Epoch 10/25
# 720/720 [==============================] - 17s 24ms/step - loss: 0.5948 - accuracy: 0.7699 - val_loss: 0.5352 - val_accuracy: 0.7991
# Epoch 11/25
# 720/720 [==============================] - 17s 23ms/step - loss: 0.5848 - accuracy: 0.7745 - val_loss: 0.5398 - val_accuracy: 0.7980
# Epoch 12/25
# 720/720 [==============================] - 17s 24ms/step - loss: 0.5820 - accuracy: 0.7747 - val_loss: 0.6861 - val_accuracy: 0.6150
# Epoch 13/25
# 720/720 [==============================] - 16s 23ms/step - loss: 0.5904 - accuracy: 0.7691 - val_loss: 0.5725 - val_accuracy: 0.7647
# Epoch 14/25
# 720/720 [==============================] - 17s 23ms/step - loss: 0.6092 - accuracy: 0.7640 - val_loss: 0.5307 - val_accuracy: 0.7852
# Epoch 15/25
# 720/720 [==============================] - 17s 24ms/step - loss: 0.5821 - accuracy: 0.7713 - val_loss: 0.5167 - val_accuracy: 0.8032
# Epoch 16/25
# 720/720 [==============================] - 17s 24ms/step - loss: 0.6061 - accuracy: 0.7712 - val_loss: 0.4888 - val_accuracy: 0.8187
# Epoch 17/25
# 720/720 [==============================] - 17s 23ms/step - loss: 0.6689 - accuracy: 0.7452 - val_loss: 0.6150 - val_accuracy: 0.7817
# Epoch 18/25
# 720/720 [==============================] - 17s 23ms/step - loss: 0.6679 - accuracy: 0.7624 - val_loss: 0.5928 - val_accuracy: 0.7862
# Epoch 19/25
# 720/720 [==============================] - 17s 23ms/step - loss: 0.6184 - accuracy: 0.7767 - val_loss: 0.6129 - val_accuracy: 0.7820
# Epoch 20/25
# 720/720 [==============================] - 17s 24ms/step - loss: 0.6867 - accuracy: 0.7626 - val_loss: 0.5642 - val_accuracy: 0.8071
# Epoch 21/25
# 720/720 [==============================] - 17s 23ms/step - loss: 0.6528 - accuracy: 0.7676 - val_loss: 0.6309 - val_accuracy: 0.7730
# Epoch 22/25
# 720/720 [==============================] - 17s 24ms/step - loss: 0.6600 - accuracy: 0.7574 - val_loss: 0.5799 - val_accuracy: 0.7734
# Epoch 23/25
# 720/720 [==============================] - 17s 23ms/step - loss: 0.6443 - accuracy: 0.7548 - val_loss: 0.6062 - val_accuracy: 0.7758
# Epoch 24/25
# 720/720 [==============================] - 18s 24ms/step - loss: 0.6360 - accuracy: 0.7624 - val_loss: 0.5709 - val_accuracy: 0.7888
# Epoch 25/25
# 720/720 [==============================] - 17s 23ms/step - loss: 0.6307 - accuracy: 0.7645 - val_loss: 0.5622 - val_accuracy: 0.7932

# %%
rate0_0005 = train_model()
# Out:
# Found 28793 files belonging to 5 classes.
# Using 23035 files for training.
# Found 28793 files belonging to 5 classes.
# Using 5758 files for validation.
# Epoch 1/25
# 720/720 [==============================] - 22s 24ms/step - loss: 0.6476 - accuracy: 0.7435 - val_loss: 0.4680 - val_accuracy: 0.8041
# Epoch 2/25
# 720/720 [==============================] - 18s 26ms/step - loss: 0.4848 - accuracy: 0.7973 - val_loss: 0.4217 - val_accuracy: 0.8277
# Epoch 3/25
# 720/720 [==============================] - 18s 25ms/step - loss: 0.4526 - accuracy: 0.8096 - val_loss: 0.4187 - val_accuracy: 0.8242
# Epoch 4/25
# 720/720 [==============================] - 18s 26ms/step - loss: 0.4379 - accuracy: 0.8174 - val_loss: 0.3903 - val_accuracy: 0.8369
# Epoch 5/25
# 720/720 [==============================] - 18s 24ms/step - loss: 0.4188 - accuracy: 0.8255 - val_loss: 0.3794 - val_accuracy: 0.8414
# Epoch 6/25
# 720/720 [==============================] - 17s 24ms/step - loss: 0.4090 - accuracy: 0.8316 - val_loss: 0.3582 - val_accuracy: 0.8506
# Epoch 7/25
# 720/720 [==============================] - 17s 24ms/step - loss: 0.3992 - accuracy: 0.8333 - val_loss: 0.3558 - val_accuracy: 0.8562
# Epoch 8/25
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3906 - accuracy: 0.8410 - val_loss: 0.3697 - val_accuracy: 0.8503
# Epoch 9/25
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3817 - accuracy: 0.8438 - val_loss: 0.3545 - val_accuracy: 0.8536
# Epoch 10/25
# 720/720 [==============================] - 19s 26ms/step - loss: 0.3823 - accuracy: 0.8454 - val_loss: 0.3494 - val_accuracy: 0.8626
# Epoch 11/25
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3683 - accuracy: 0.8509 - val_loss: 0.3551 - val_accuracy: 0.8583
# Epoch 12/25
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3667 - accuracy: 0.8521 - val_loss: 0.3748 - val_accuracy: 0.8503
# Epoch 13/25
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3673 - accuracy: 0.8514 - val_loss: 0.3349 - val_accuracy: 0.8668
# Epoch 14/25
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3643 - accuracy: 0.8537 - val_loss: 0.3476 - val_accuracy: 0.8631
# Epoch 15/25
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3580 - accuracy: 0.8549 - val_loss: 0.3432 - val_accuracy: 0.8593
# Epoch 16/25
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3543 - accuracy: 0.8543 - val_loss: 0.3321 - val_accuracy: 0.8647
# Epoch 17/25
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3510 - accuracy: 0.8583 - val_loss: 0.3385 - val_accuracy: 0.8598
# Epoch 18/25
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3456 - accuracy: 0.8618 - val_loss: 0.3350 - val_accuracy: 0.8635
# Epoch 19/25
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3446 - accuracy: 0.8603 - val_loss: 0.3263 - val_accuracy: 0.8746
# Epoch 20/25
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3413 - accuracy: 0.8618 - val_loss: 0.3260 - val_accuracy: 0.8682
# Epoch 21/25
# 720/720 [==============================] - 16s 22ms/step - loss: 0.3370 - accuracy: 0.8654 - val_loss: 0.3743 - val_accuracy: 0.8482
# Epoch 22/25
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3386 - accuracy: 0.8632 - val_loss: 0.3045 - val_accuracy: 0.8788
# Epoch 23/25
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3393 - accuracy: 0.8656 - val_loss: 0.3131 - val_accuracy: 0.8765
# Epoch 24/25
# 720/720 [==============================] - 17s 23ms/step - loss: 0.3363 - accuracy: 0.8639 - val_loss: 0.3116 - val_accuracy: 0.8795
# Epoch 25/25
# 720/720 [==============================] - 16s 23ms/step - loss: 0.3275 - accuracy: 0.8672 - val_loss: 0.3370 - val_accuracy: 0.8696

# %%
# !mkdir learning_rate
pd.DataFrame(rate0_01).to_csv("learning_rate/rate0_01.csv", index=False)
pd.DataFrame(rate0_0005).to_csv("learning_rate/rate0_0005.csv", index=False)
